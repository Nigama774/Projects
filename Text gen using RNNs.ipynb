# %% [markdown]
# # Importing the libraries

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# # Text processing

# %% [markdown]
# Sample text for training

# %%
text = "yes chatgpt I have overcome procrastination many years earlier after particular and focused effort. Now that feeling is back and fills me with dread. When i try to learn something you see."

# %% [markdown]
# Tokenize the text

# %%
tokenizer = Tokenizer(char_level=True)  # Tokenizing at character level
tokenizer.fit_on_texts([text])
total_chars = len(tokenizer.word_index) + 1  # Total unique characters

# %% [markdown]
# Create sequences

# %%
input_sequences = []
for i in range(1, len(text)):
    seq = text[:i + 1]
    encoded = tokenizer.texts_to_sequences([seq])[0]
    input_sequences.append(encoded)

# %% [markdown]
# Pad sequences to ensure uniform length

# %%
max_seq_len = max([len(seq) for seq in input_sequences])
input_sequences = pad_sequences(input_sequences, maxlen=max_seq_len, padding='pre')

# %% [markdown]
# Split into inputs (X) and targets (y)

# %%
X = input_sequences[:, :-1]
y = input_sequences[:, -1]
y = tf.keras.utils.to_categorical(y, num_classes=total_chars)

# %% [markdown]
# # Build the RNN model

# %%
model = Sequential([
    Embedding(total_chars, 50, input_length=max_seq_len - 1),  # Embedding layer
    LSTM(100, return_sequences=False),  # LSTM layer
    Dense(total_chars, activation='softmax')  # Output layer
])

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)              │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# #Train the model

# %%
model.fit(X, y, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - accuracy: 0.0518 - loss: 3.2156
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - accuracy: 0.1262 - loss: 3.1842
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - accuracy: 0.1619 - loss: 3.0591
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - accuracy: 0.1698 - loss: 2.9296
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - accuracy: 0.1637 - loss: 2.9114
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - accuracy: 0.1645 - loss: 2.8959
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 175ms/step - accuracy: 0.1615 - loss: 2.8675
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 213ms/step - accuracy: 0.1786 - loss: 2.8714
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.1800 - loss: 2.8627
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.1765 - loss: 2.8717
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - accuracy: 0.1745 - loss: 2.7998
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - accuracy: 0.1470 - loss: 2.9019
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - accuracy: 0.1622 - loss: 2.8247
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - accuracy: 0.1539 - loss: 2.8509
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - accuracy: 0.1572 - loss: 2.8140
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - accuracy: 0.1468 - loss: 2.8315
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - accuracy: 0.1640 - loss: 2.8119
# Epoch 18/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 186ms/step - accuracy: 0.1640 - loss: 2.7514
# Epoch 19/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 208ms/step - accuracy: 0.2175 - loss: 2.7388
# Epoch 20/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - accuracy: 0.2242 - loss: 2.6650
# Epoch 21/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - accuracy: 0.2192 - loss: 2.6302
# Epoch 22/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - accuracy: 0.2227 - loss: 2.6524
# Epoch 23/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - accuracy: 0.2430 - loss: 2.6255
# Epoch 24/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - accuracy: 0.2001 - loss: 2.6776
# Epoch 25/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - accuracy: 0.2343 - loss: 2.5322
# Epoch 26/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - accuracy: 0.2730 - loss: 2.4678
# Epoch 27/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - accuracy: 0.2730 - loss: 2.5289
# Epoch 28/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - accuracy: 0.2588 - loss: 2.4270
# Epoch 29/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - accuracy: 0.3065 - loss: 2.3535
# Epoch 30/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - accuracy: 0.3162 - loss: 2.2459
# Epoch 31/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 208ms/step - accuracy: 0.3034 - loss: 2.2500
# Epoch 32/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 224ms/step - accuracy: 0.3459 - loss: 2.2213
# Epoch 33/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - accuracy: 0.3259 - loss: 2.1598
# Epoch 34/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - accuracy: 0.3828 - loss: 2.1107
# Epoch 35/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - accuracy: 0.3633 - loss: 2.0543
# Epoch 36/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - accuracy: 0.3762 - loss: 1.9822
# Epoch 37/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.4151 - loss: 2.0103
# Epoch 38/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - accuracy: 0.3987 - loss: 2.0465
# Epoch 39/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.4621 - loss: 1.8671
# Epoch 40/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - accuracy: 0.4237 - loss: 1.8804
# Epoch 41/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - accuracy: 0.4924 - loss: 1.7467
# Epoch 42/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - accuracy: 0.4259 - loss: 1.7600
# Epoch 43/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 214ms/step - accuracy: 0.5011 - loss: 1.7263
# Epoch 44/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 205ms/step - accuracy: 0.5205 - loss: 1.6350
# Epoch 45/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - accuracy: 0.5458 - loss: 1.6168
# Epoch 46/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - accuracy: 0.5241 - loss: 1.5953
# Epoch 47/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - accuracy: 0.5679 - loss: 1.5380
# Epoch 48/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - accuracy: 0.6039 - loss: 1.4986
# Epoch 49/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - accuracy: 0.6068 - loss: 1.4242
# Epoch 50/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - accuracy: 0.5923 - loss: 1.4201
# Epoch 51/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - accuracy: 0.6236 - loss: 1.3601
# Epoch 52/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.6593 - loss: 1.2680
# Epoch 53/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - accuracy: 0.6706 - loss: 1.2828
# Epoch 54/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 174ms/step - accuracy: 0.7164 - loss: 1.2272
# Epoch 55/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 213ms/step - accuracy: 0.6851 - loss: 1.1993
# Epoch 56/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 222ms/step - accuracy: 0.7600 - loss: 1.1161
# Epoch 57/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - accuracy: 0.6881 - loss: 1.1348
# Epoch 58/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.7921 - loss: 1.0738
# Epoch 59/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.7629 - loss: 1.0935
# Epoch 60/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.8060 - loss: 1.0090
# Epoch 61/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - accuracy: 0.8408 - loss: 0.9821
# Epoch 62/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - accuracy: 0.7674 - loss: 0.9768
# Epoch 63/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - accuracy: 0.8281 - loss: 0.9486
# Epoch 64/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - accuracy: 0.8462 - loss: 0.9207
# Epoch 65/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - accuracy: 0.8354 - loss: 0.8871
# Epoch 66/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.8932 - loss: 0.8177
# Epoch 67/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step - accuracy: 0.8900 - loss: 0.7888
# Epoch 68/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 212ms/step - accuracy: 0.8920 - loss: 0.7684
# Epoch 69/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 213ms/step - accuracy: 0.8788 - loss: 0.8015
# Epoch 70/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - accuracy: 0.8892 - loss: 0.7544
# Epoch 71/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - accuracy: 0.9367 - loss: 0.7019
# Epoch 72/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - accuracy: 0.9253 - loss: 0.7135
# Epoch 73/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - accuracy: 0.9247 - loss: 0.7134
# Epoch 74/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - accuracy: 0.9475 - loss: 0.6660
# Epoch 75/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - accuracy: 0.9387 - loss: 0.6417
# Epoch 76/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - accuracy: 0.9417 - loss: 0.6383
# Epoch 77/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - accuracy: 0.9543 - loss: 0.5811
# Epoch 78/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - accuracy: 0.9607 - loss: 0.5921
# Epoch 79/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.9654 - loss: 0.5617
# Epoch 80/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 209ms/step - accuracy: 0.9574 - loss: 0.5710
# Epoch 81/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 222ms/step - accuracy: 0.9800 - loss: 0.5323
# Epoch 82/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - accuracy: 0.9672 - loss: 0.5080
# Epoch 83/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.9892 - loss: 0.4959
# Epoch 84/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - accuracy: 0.9842 - loss: 0.4925
# Epoch 85/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - accuracy: 0.9875 - loss: 0.4731
# Epoch 86/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.9862 - loss: 0.4365
# Epoch 87/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - accuracy: 0.9903 - loss: 0.4333
# Epoch 88/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - accuracy: 0.9950 - loss: 0.4455
# Epoch 89/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - accuracy: 0.9934 - loss: 0.4109
# Epoch 90/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - accuracy: 0.9929 - loss: 0.3833
# Epoch 91/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - accuracy: 1.0000 - loss: 0.3824
# Epoch 92/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 216ms/step - accuracy: 0.9976 - loss: 0.3766
# Epoch 93/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 211ms/step - accuracy: 1.0000 - loss: 0.3651
# Epoch 94/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - accuracy: 1.0000 - loss: 0.3555
# Epoch 95/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - accuracy: 1.0000 - loss: 0.3499
# Epoch 96/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - accuracy: 1.0000 - loss: 0.3157
# Epoch 97/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - accuracy: 1.0000 - loss: 0.3291
# Epoch 98/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - accuracy: 1.0000 - loss: 0.3162
# Epoch 99/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - accuracy: 1.0000 - loss: 0.3009
# Epoch 100/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - accuracy: 1.0000 - loss: 0.3025

# %% [markdown]
# # Text generation function

# %%
def generate_text(seed_text, next_chars=100):
    for _ in range(next_chars):
        # Encode seed text
        encoded = tokenizer.texts_to_sequences([seed_text])[0]
        encoded = pad_sequences([encoded], maxlen=max_seq_len - 1, padding='pre')

        # Predict next character
        predicted = np.argmax(model.predict(encoded, verbose=0), axis=-1)
        next_char = tokenizer.sequences_to_texts([[predicted[0]]])[0]

        # Append to seed text
        seed_text += next_char

    return seed_text

# %% [markdown]
# # Generate text

# %%
seed_text = "yes chatgpt I have overcome"
generated_text = generate_text(seed_text, next_chars=100)
print("Generated Text:")
print(generated_text)
# Out:
# Generated Text:
# yes chatgpt I have overcome procrastination many years earlier after particular and focused effort. now that feeling is back an
